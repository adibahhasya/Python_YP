# %%
#GUI means desktop based appplication 
#import tkinter

# source of documentation (file notes: https://drive.google.com/file/d/1VgWiksdB6P8q4c8UqS_3QttF35POo0tC/view)

# %%
# Tk() : to create a main window, tkinter offers a method Tk()
# m = tkinter.Tk() # where m is the name of the main window object 
# mainloop(): there is a method known by the name mainloop() is used when your application is ready to run.
# mainloop() is an infinite loop used to run the application, wait for an event to occur and process the event as long as the window is not closed.

# %%
# Tkinter GUI
# First GUI Application

from tkinter import * #1: use tkinter module 
# 2: Create application main window
myWindow = Tk()

# 3: entering the main Loop
myWindow.mainloop()

# %%
# Setting the title for Tkinter App
myWindow = Tk()
myWindow.title ('Tkinter App')
myWindow.mainloop()

# %%
#Tkinter Button Widget and pack() method

#1 create a button
w = Tk()
w.title('Button Widget')

redButton = Button(w,text='RedButton', fg='red') #CREATE A BUTTON 
redButton.pack() #by default pack method place the widget at the TOP of the application window


#pack() method is place where you want to put the button
blackButton = Button(w,text='BlackButton', fg='black')
blackButton.pack(side = LEFT)

blueButton = Button(w,text='BlueButton', fg='blue')
blueButton.pack(side = RIGHT)

greenButton = Button(w,text='GreenButton', fg='green')
greenButton.pack(side = BOTTOM)

w.mainloop()

# %%
# Command option of Button Widget 
# Using command option you can call a python function 
# can manage the event handling as well

import tkinter.messagebox as mb

def func():
    mb.showinfo('Hello', 'Button is Clicked')
                #title     #Message
#1 create a button
w = Tk()
w.title('Button Widget')

myButton = Button(w,text='Click Me', command =func, activeforeground='red', activebackground='pink') #command tu akan ada keluarkan button aftert click button
#kalau tekan dekat button click me tu nanti text colour red, and background colour pink
myButton.pack() 


w.mainloop()

# %%
# Entry Widget / Label Widget / place() / geometry()

w = Tk()
w.title('Entry Widget')

# set the width and height of my application window
w.geometry('400x250') #width x height 

nameLabel = Label(w, text = 'Enter Name').place(x=30,y=50) # x means margin from left
emailLabel = Label(w, text = 'Enter Email').place(x=30,y=90) # x means margin from left

e1 = Entry(w).place(x=120,y=50) #pass value nameLabel
e2 = Entry(w).place(x=120,y=90) #pass value email label
w.mainloop()

# %%
# Menu Widget 

def help1():
    mb.showinfo('My App', 'Copyright All Rights Reserved Version 1.0 | 2024')

w = Tk()
w.title('Menu Widget')

w.geometry('400x250') 

menubar = Menu(w)
menubar.add_command(label='File')
menubar.add_command(label='Edit')
menubar.add_command(label='View')
menubar.add_command(label='Help', command=help1)
menubar.add_command(label='Exit', command=w.destroy)

#display the menu bar
w.config(menu=menubar)

w.mainloop()

# %%
w = Tk()
w.title('Menu Widget')
w.geometry('400x250') 

menubar = Menu(w)


file_sub_menu = Menu(menubar, tearoff=0)
file_sub_menu.add_command(label='New')
file_sub_menu.add_command(label='Open')
file_sub_menu.add_command(label='Save')
file_sub_menu.add_separator()
file_sub_menu.add_command(label = 'Save As')
file_sub_menu.add_command(label = 'Download')
menubar.add_cascade(label='File', menu=file_sub_menu)

edit_sub_menu = Menu(menubar, tearoff = 0)
edit_sub_menu.add_command(label='Cut')
edit_sub_menu.add_command(label='Copy')
edit_sub_menu.add_command(label='Paste')
menubar.add_cascade(label='Edit', menu=edit_sub_menu)

#display the menu bar
w.config(menu=menubar)

w.mainloop()

# %%
# RadioButton Widget 

w = Tk()
w.title('Radio Button Widget')
w.geometry('400x250') 

#here we need to declare one variable for a variable button 
radioVar = IntVar()

# a variable can store only one value at a time

r1=Radiobutton(w,text='Male', variable=radioVar, value = 1)
r1.pack()

r2=Radiobutton(w,text='Female', variable=radioVar, value = 2)
r2.pack()

r3=Radiobutton(w,text='Other',  variable=radioVar, value = 3)
r3.pack()

w.mainloop()

# %%
# Basic Calculator to Add 2 Numbers

w = Tk()
w.title('My Simple Calculator')
w.geometry('400x250') 

def addTwoNumbers():
    res = int(e1.get()) + int(e2.get())
    outputText = 'After Addition Result Will Be : ' +str(res)
    outputLabel.config(text=outputText)

val1=Label(w, text  = 'Enter First Value').place(x=30,y=50)
val2=Label(w, text  = 'Enter Second Value').place(x=30,y=90)


e1 = Entry(w)
e1.place(x=150,y=50)

e2 = Entry(w)
e2.place(x=150,y=90)

addButton = Button(w,text='Click Here To Add', command=addTwoNumbers)
addButton.place(x=120,y=140)

outputLabel = Label(w)
outputLabel.place(x=80,y=190)


w.mainloop()

# %%
# Guess a number game 
from tkinter import * 
import random 
w = Tk()
w.title('Guess A number Game')
w.geometry('600x400') 

# background colour for window 
w.config(bg='#065569')
w.resizable(width=False, height =False)

#main logic 
ranNum=random.randint(1,10)
chance = 4
displayResult = StringVar()

def check_guess():
    global ranNum
    global chance
    userInput = int(user_input.get())
    if chance > 0: 
        if userInput == ranNum:
            msg = "Congratulations. You Won! " + str(ranNum) + " is the right number"
            user_input.config(state='disabled')
            guess_button.config(state='disabled')
        elif userInput > ranNum:
            chance = chance - 1
            msg = "Your Guess Is Too High. Think of a smaller number"
            user_input.delete(0,END)
        elif userInput < ranNum:
            chance = chance - 1
            msg = "Your Guess Is Too Low. Think of a higher number"
            user_input.delete(0,END)
    else: 
        msg = "Game Over! 0 Attempts Left. The Correct Number Was " + str(ranNum)
        user_input.config(state='disabled')
        guess_button.config(state='disabled')

    displayResult.set(msg)

#Create Widgets 
title=Label(w,text='Guess A number Game', font=('Arial', 20), fg='#fffcbd',bg='#065569')
gameInstruction=Label(w,text='Guess A number between 1 to 10 in 4 attempts', font=('Arial', 13), fg='#fffcbd',bg='#065569')
user_input=Entry(w,font=('Arial', 12))
guess_button = Button(w,text='Guess',font=('Arial',13),fg='#13d675',bg='black',command=check_guess)
exit_button = Button(w,text='Exit Game',font=('Arial',13),fg='white',bg='#b82741',command=w.destroy)
outputLabel = Label(w,text='Hints/Result', font=('Arial', 14), fg='#fffcbd',bg='#065569', textvariable=displayResult)
      
#Place Widgets
title.place(x=140,y=50)
gameInstruction.place(x=95,y=95)
user_input.place(x=180,y=150)
guess_button.place(x=370,y=147)
exit_button.place(x=300,y=300)
outputLabel.place(x=100,y=220)

w.mainloop()

# %%
# Sentiment Analysis
# Sentiment analysis is the process of analyzing digital text
# to determine if the emotional tone of the message is positive,
# negative, or neutral. Today, companies have large volumes of
# text data like emails, customer support chat transcripts,
# social media comments, and reviews. Sentiment analysis tools
# can scan this text to automatically determine the author’s
# attitude towards a topic. Companies use the insights from
# sentiment analysis to improve customer service and increase brand reputation.

# VADER
# VADER stands for Valence Aware Dictionary and Sentiment Reasoner.
# It’s a tool used for sentiment analysis, which is basically a
# way to figure out if a piece of text is expressing positive,
# negative, or neutral emotions.

# VADER doesn’t just say positive or negative,
# it assigns a score between -1 (most negative)
# and +1 (most positive) to show how strong the sentiment is.

# Research suggests VADER achieves the score of 0.96 for sentiment classification.

# The SentimentIntensityAnalyzer class provides a method called polarity_scores()
# that takes a piece of text as input and returns a dictionary containing
# the sentiment scores for the text.
# The dictionary contains four keys: neg, neu, pos, and compound.

# %%
# !pip install vaderSentiment
# !pip install textblob
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: requests in c:\users\hasya-zanroomy\appdata\roaming\python\python313\site-packages (from vaderSentiment) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hasya-zanroomy\appdata\roaming\python\python313\site-packages (from requests->vaderSentiment) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hasya-zanroomy\appdata\roaming\python\python313\site-packages (from requests->vaderSentiment) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hasya-zanroomy\appdata\roaming\python\python313\site-packages (from requests->vaderSentiment) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hasya-zanroomy\appdata\roaming\python\python313\site-packages (from requests->vaderSentiment) (2025.7.14)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: nltk>=3.9 in c:\users\hasya-zanroomy\anaconda3\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\hasya-zanroomy\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in c:\users\hasya-zanroomy\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hasya-zanroomy\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\hasya-zanroomy\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\hasya-zanroomy\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 624.3/624.3 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.19.0

# %%
# Sentiment Analyzer App

from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
sid_obj=SentimentIntensityAnalyzer()


w = Tk()
w.title('Sentiment Analyzer')
w.geometry('600x400') 

# background colour for window 
w.config(bg='#6482AD')
w.resizable(width=False, height =False)


#main logic
displayResult = StringVar()

def check_sentiment():
    userInput=user_input.get()
    res=TextBlob(userInput)
    res=sid_obj.polarity_scores(res)

    if res['compound'] >= 0.5:
        displayResult.set('Positive Text')
        user_input.delete(0, END)
    elif res['compound'] <= -0.5:
        displayResult.set('Negative Text')
        user_input.delete(0, END)
    else:
        displayResult.set('Neutral Text')
        user_input.delete(0, END)

# Create Widgets
title = Label(w,text='Sentiment Analyzer Please Insert Some Text Below',font=('Arial', 14),fg='#F5EDED',bg='#6482AD')
user_input = Entry(w,font=('Arial',14))
button1=Button(w,text='Click Here To Analze',font=('Arial', 13),fg='#7C00FE',
               bg='#BC9F8B',  command=check_sentiment)
outputLabel = Label(w,font=('Arial',18),fg='#522258',bg='#6482AD', textvariable=displayResult)



# Place Widgets
title.place(x=60,y=50)
user_input.place(x=150,y=120)
button1.place(x=390,y=120)
outputLabel.place(x=250,y=200)

w.mainloop()
