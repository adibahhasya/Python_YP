# %% [markdown]
# ##OBJECT-ORIENTED PROGRAMMING

# %%
# OOPS
# OOP stands for Object-Oriented Programming.
# Object-oriented programming (OOP) is a programming paradigm based on the
# concept of "objects"

# Procedural programming is about writing procedures or methods that perform operations
# on the data, while object-oriented programming is about creating objects
# that contain both data and methods.

# Object-oriented programming has several advantages over procedural programming:

# a.) OOP is faster and easier to execute
# b.) OOP provides a clear structure for the programs
# c.) OOP helps to keep the Java/Python code DRY "Don't Repeat Yourself", and makes the code easier
#     to maintain, modify and debug
# d.) OOP makes it possible to create full reusable applications with less code and
#     shorter development time

# Class
# A class is a blueprint that defines the variables and the methods common to all objects.
# a class is a collection of methods and variables


# Object
# An object is called an instance of a class.


# Self Keyword
# The self parameter is a reference to the current instance of the class, and is used to
# access variables that belongs to the class.
# The first parameter of each method in a class must be the self ,
# which refers to the calling object. However, you can give any name to the first
# parameter, not necessarily self.

# __init__ in Python
#  Constructors are used to initializing the object’s state. The task of constructors is
# to initialize(assign values) to the data members of the class when
# an object of the class is created.
# The __init__() function is called automatically every time the class is being used to create
# a new object.

# %%
#A class is a collection of variables and method
#In a python we define class using class keyword

class myclass:

 ''' this is my first class in python programming oops'''
 a=10
 b=20

 def func1():
  print('Hi, I am a class function')

  def func2():
    print('Hi, I am another class function')

# %%
help(myclass)
# Out:
# Help on class myclass in module __main__:
#
# class myclass(builtins.object)
#  |  this is my first class in python programming oops
#  |
#  |  Methods defined here:
#  |
#  |  func1()
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  a = 10
#  |
#  |  b = 20

# %%
class myclass:

 a=10  #member variables
 b=20

 def func1():  #member method
  print('Hi, I am a class function')

  def func2():
    print('Hi, I am another class function')

print(myclass.a)
print(myclass.func1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1773762255.py in <cell line: 0>()
#      10     print('Hi, I am another class function')
#      11
# ---> 12 print(myclass.a)
#      13 print(myclass.func1)
#
# TypeError: 'str' object is not callable

# %%
#use self keyword
#first parameter of a class function should be SELF

#self represent

class myclass:

 a=10
 b=20

 def func1(self):                            #func1(obj1) func(obj2)
  print('Hi, I am a class function')

  def func2(self):
    print('Hi, I am another class function')

obj1=myclass()
obj2=myclass()

print(obj1.a)
print(obj2.a)

obj1.func1()
obj2.func1()

obj1.func2()
obj2.func2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-743410861.py in <cell line: 0>()
#      18 obj2=myclass()
#      19
# ---> 20 print(obj1.a)
#      21 print(obj2.a)
#      22
#
# TypeError: 'str' object is not callable

# %%
# use self keyword
# first parameter of a class function must be SELF

# self represent the current calling instance (object)

class myclass:

  a = 10
  b = 20

  def func1(self):                           #  func1(obj1)      func1(obj2)
    print('Hi I am a class function')

  def func2(self):
    print('Hi I am another class function')


obj1 = myclass()
obj2 = myclass()

print(obj1.a)
print(obj2.a)

obj1.func1()
obj2.func1()

obj1.func2()
obj2.func2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1048812691.py in <cell line: 0>()
#      19 obj2 = myclass()
#      20
# ---> 21 print(obj1.a)
#      22 print(obj2.a)
#      23
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Try to solve this problem for me
#
# WAP to take 3 details from 3 users

# %%
#Company --> Workshop
#Register people in the workshop


#user1 wants to register, [name, email, mobno]

#user2 wants to register, [name, email, mobno]

#user2 wants to register, [name, email, mobno]

#a) print all information
#b) print the information for 2nd user
#C) PRINT THE MOBNO OF 3RD  user

# %%
# Function to register users
def register_users():
    users = []  # List to store user details

    # Register 3 users
    for i in range(3):
        print(f"Register user {i+1}:")
        name = input("Enter name: ")
        email = input("Enter email: ")
        mobno = input("Enter mobile number: ")
        users.append({"name": name, "email": email, "mobno": mobno})
        print()

    return users

# Function to display all user information
def print_all_users(users):
    print("All Registered Users Information:")
    for i, user in enumerate(users):
        print(f"User {i+1}: {user}")
    print()

# Function to display information of the second user
def print_second_user(users):
    if len(users) >= 2:
        print("Second User Information:")
        print(users[1])
        print()
    else:
        print("Second user is not available.\n")

# Function to print mobile number of the third user
def print_third_user_mobno(users):
    if len(users) >= 3:
        print(f"Mobile number of Third User: {users[2]['mobno']}\n")
    else:
        print("Third user is not available.\n")

# Main code execution
users = register_users()  # Register 3 users
print_all_users(users)  # Print all user details
print_second_user(users)  # Print details of the second user
print_third_user_mobno(users)  # Print the mobile number of the third user

# %%
# Create an empty list to store user details
users = []

# Register 3 users by asking for their details
for i in range(3):
    print(f"Register user {i+1}:")
    name = input("Enter name: ")
    email = input("Enter email: ")
    mobno = input("Enter mobile number: ")
    users.append({"name": name, "email": email, "mobno": mobno})
    print()  # Add a blank line for clarity

# a) Print all information of all registered users
print("All Registered Users Information:")
for i in range(3):
    print(f"User {i+1}: {users[i]}")

# b) Print the information for the 2nd user
if len(users) >= 2:
    print("\nSecond User Information:")
    print(users[1])
else:
    print("\nSecond user is not available.")

# c) Print the mobile number of the 3rd user
if len(users) >= 3:
    print("\nMobile number of Third User:")
    print(users[2]['mobno'])
else:
    print("\nThird user is not available.")

# %%
# Store user information
users = []

# Use loop to take input for 3 users
for i in range(1, 4):
    print(f"\nEnter details for User {i}:")
    name = input("Enter name: ")
    email = input("Enter email: ")
    mob_no = input("Enter mobile number: ")

    # Store the info as a dictionary
    user_info = {
        "Name": name,
        "Email": email,
        "Mobile No": mob_no
    }

    users.append(user_info)

# a) Print all information
print("\n--- All Users Information ---")
for i, user in enumerate(users, start=1):
    print(f"\nUser {i}:")
    for key, value in user.items():
        print(f"{key}: {value}")

# b) Print all information for 2nd user only
print("\n--- Information for 2nd User ---")
for key, value in users[1].items():
    print(f"{key}: {value}")

# c) Print all information for 3rd user only
print("\n--- Information for 3rd User ---")
for key, value in users[2].items():
    print(f"{key}: {value}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4284663143.py in <cell line: 0>()
#       4 # Use loop to take input for 3 users
#       5 for i in range(1, 4):
# ----> 6     print(f"\nEnter details for User {i}:")
#       7     name = input("Enter name: ")
#       8     email = input("Enter email: ")
#
# TypeError: 'str' object is not callable

# %%
users = []
for i in range(3):
    print(f"\nEnter details for user{i+1}:")
    name = input("Enter name: ")
    email = input("Enter email: ")
    mobno = input("Enter mobile number: ")
    users.append([name, email, mobno])

# a.) print all information
print("\nAll User Information")
for i, user in enumerate(users, start=1):
    print(f"User{i}: Name = {user[0]}, Email = {user[1]}, Mobile = {user[2]}")

# b.) print the information for 2nd user
print("\nInformation for 2nd User")
print(f"Name = {users[1][0]}, Email = {users[1][1]}, Mobile = {users[1][2]}")

# c.) print the mobno of 3rd user
print("\nMobile number of 3rd user")
print(users[2][2])

# %%
'''When you use loops, lists, dictionaries, and functions (but not classes/objects)

→ you are following the Procedural Programming approach


You organize code into procedures (functions) and use control structures like loops (for, while), conditionals (if, else), and data structures (list, dict, etc.) to handle data.
'''
